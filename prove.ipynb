# %%
import matplotlib.pyplot as plt
  
x = list(range(10))
y = [i**2 for i in x]
fig, ax = plt.figure(), plt.axes()

ax.plot(x,y)
ax.set(title="Plot", xlabel="x", ylabel="y")

import matplotlib.pyplot as plt
x = range(5)
y = [i**2 for i in x]

fig, axs = plt.subplots(1, 2)  # two subplots side by side

axs[0].plot(x, y)
axs[0].set_title("First plot")
axs[0].set_xlabel("x-axis")
axs[0].set_ylabel("y-axis")

axs[1].plot(x, [i*2 for i in x])
axs[1].set_title("Second plot")
axs[1].set_xlabel("x-axis")
axs[1].set_ylabel("y-axis")

plt.show()  # spacing may overlap

# %% [markdown]
# 1 Betrakta f¨oljande kod:
#
#  1 import matplotlib.pyplot as plt
#  2 x = list(range(10))
#  3 y = [i**2 for i in x]
#  4 fig, ax = plt.figure(), plt.axes()
#  5 ax.plot(x,y)
#  6 ax.set(title="Plot", xlabel="x", ylabel="y")
#
#   Beskriv vad koden g¨or och vad som ritas upp. 3
#
# the firs line you add a libry to use,
# the second line x is a variable that is a list in
#
#
# 2 Vadskrivs ut av f¨oljande kod? 3p
#
#  1 frukter = ["jordgubbe", "vindruva", "grape"]
#  2 godfrukt = frukter[2]
#  3 print(godfrukt[-1])

# %%
frukter = ["jordgubbe", "vindruva", "grape"]
godfrukt = frukter[2]
print(godfrukt[-1])
# Out:
# e

# %% [markdown]
# def print_row(input_array):
#
# for i in input_array:
# print(f"{int(i[0])}: {i[1:]} ")
# A = "1 Alice\n2 Bob"
# print_row(A)
#
# Felet ¨ar ett ValueError men du har inte tillg˚ang till stack-trace eller felmedde
# landet.
#  Tips: En str¨ang ¨ar en lista av Char
#  a) 1p Vilken rad ¨ar det som orsakar felet?
#  b) 2p Ange hur A skall se ut f¨or att producera det v¨antade resultatet:
#  1: Alice 2: Bob

# %%
def print_row(input_array):
    for i in input_array:
        print(f"{(i[0])}: {i[1:]} ")

A = "1 Alice\n2 Bob"
print_row(A)
# Out:
# 1:
#  :
# A:
# l:
# i:
# c:
# e:
#
# :
# 2:
#  :
# B:
# o:
# b:
